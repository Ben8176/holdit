# %% [markdown]
# # 1. Import and Install Dependencies

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
# Out:
# /Users/sraswan/Documents/Workspace/holdit/.venv/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# # 2. Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# I0000 00:00:1705788637.539540       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 76.3), renderer: Apple M1 Pro
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[181], line 10
#       7 ret, frame = cap.read()
#       9 # Make detections
# ---> 10 image, results = mediapipe_detection(frame, holistic)
#      11 print(results)
#      13 # Draw landmarks
#
# Cell In[3], line 4, in mediapipe_detection(image, model)
#       2 image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
#       3 image.flags.writeable = False                  # Image is no longer writeable
# ----> 4 results = model.process(image)                 # Make prediction
#       5 image.flags.writeable = True                   # Image is now writeable
#       6 image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
#
# File ~/Documents/Workspace/holdit/.venv/lib/python3.8/site-packages/mediapipe/python/solutions/holistic.py:160, in Holistic.process(self, image)
#     136 def process(self, image: np.ndarray) -> NamedTuple:
#     137   """Processes an RGB image and returns the pose landmarks, left and right hand landmarks, and face landmarks on the most prominent person detected.
#     138
#     139   Args:
#    (...)
#     157          "enable_segmentation" is set to true.
#     158   """
# --> 160   results = super().process(input_data={'image': image})
#     161   if results.pose_landmarks:  # pytype: disable=attribute-error
#     162     for landmark in results.pose_landmarks.landmark:  # pytype: disable=attribute-error
#
# File ~/Documents/Workspace/holdit/.venv/lib/python3.8/site-packages/mediapipe/python/solution_base.py:381, in SolutionBase.process(self, input_data)
#     377 for stream_name in self._output_stream_type_info.keys():
#     378   if stream_name in self._graph_outputs:
#     379     setattr(
#     380         solution_outputs, stream_name,
# --> 381         self._get_packet_content(self._output_stream_type_info[stream_name],
#     382                                  self._graph_outputs[stream_name]))
#     383   else:
#     384     setattr(solution_outputs, stream_name, None)
#
# File ~/Documents/Workspace/holdit/.venv/lib/python3.8/site-packages/mediapipe/python/solution_base.py:623, in SolutionBase._get_packet_content(self, packet_data_type, output_packet)
#     620   return getattr(packet_getter, 'get_' +
#     621                  packet_data_type.value)(output_packet).numpy_view()
#     622 else:
# --> 623   return getattr(packet_getter, 'get_' + packet_data_type.value)(
#     624       output_packet)
#
# File ~/Documents/Workspace/holdit/.venv/lib/python3.8/site-packages/mediapipe/python/packet_getter.py:75, in get_proto(packet)
#      73 # pylint:enable=protected-access
#      74 proto_message = message_class()
# ---> 75 proto_message.ParseFromString(serialized_proto)
#      76 return proto_message
#
# File ~/Documents/Workspace/holdit/.venv/lib/python3.8/site-packages/google/protobuf/message.py:202, in Message.ParseFromString(self, serialized)
#     194 """Parse serialized protocol buffer data into this message.
#     195
#     196 Like :func:`MergeFromString()`, except we clear the object first.
#    (...)
#     199   message.DecodeError if the input cannot be parsed.
#     200 """
#     201 self.Clear()
# --> 202 return self.MergeFromString(serialized)
#
# File ~/Documents/Workspace/holdit/.venv/lib/python3.8/site-packages/google/protobuf/internal/python_message.py:1128, in _AddMergeFromStringMethod.<locals>.MergeFromString(self, serialized)
#    1126 length = len(serialized)
#    1127 try:
# -> 1128   if self._InternalParse(serialized, 0, length) != length:
#    1129     # The only reason _InternalParse would return early is if it
#    1130     # encountered an end-group tag.
#    1131     raise message_mod.DecodeError('Unexpected end-group tag.')
#    1132 except (IndexError, TypeError):
#    1133   # Now ord(buf[p:p+1]) == ord('') gets TypeError.
#
# File ~/Documents/Workspace/holdit/.venv/lib/python3.8/site-packages/google/protobuf/internal/python_message.py:1195, in _AddMergeFromStringMethod.<locals>.InternalParse(self, buffer, pos, end)
#    1193   pos = new_pos
#    1194 else:
# -> 1195   pos = field_decoder(buffer, new_pos, end, self, field_dict)
#    1196   if field_desc:
#    1197     self._UpdateOneofState(field_desc)
#
# File ~/Documents/Workspace/holdit/.venv/lib/python3.8/site-packages/google/protobuf/internal/decoder.py:705, in MessageDecoder.<locals>.DecodeRepeatedField(buffer, pos, end, message, field_dict)
#     703   raise _DecodeError('Truncated message.')
#     704 # Read sub-message.
# --> 705 if value.add()._InternalParse(buffer, pos, new_pos) != new_pos:
#     706   # The only reason _InternalParse would return early is if it
#     707   # encountered an end-group tag.
#     708   raise _DecodeError('Unexpected end-group tag.')
#     709 # Predict that the next tag is another copy of the same repeated field.
#
# File ~/Documents/Workspace/holdit/.venv/lib/python3.8/site-packages/google/protobuf/internal/python_message.py:1158, in _AddMergeFromStringMethod.<locals>.InternalParse(self, buffer, pos, end)
#    1145 """Create a message from serialized bytes.
#    1146
#    1147 Args:
#    (...)
#    1154   Message object.
#    1155 """
#    1156 # Guard against internal misuse, since this function is called internally
#    1157 # quite extensively, and its easy to accidentally pass bytes.
# -> 1158 assert isinstance(buffer, memoryview)
#    1159 self._Modified()
#    1160 field_dict = self._fields
#
# KeyboardInterrupt:

# %%
draw_landmarks(frame, results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # 3. Extract Keypoint Values

# %%
len(results.left_hand_landmarks.landmark)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[184], line 1
# ----> 1 len(results.left_hand_landmarks.landmark)
#
# AttributeError: 'NoneType' object has no attribute 'landmark'

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
face
# Out:
# array([ 0.50819898,  0.31620559, -0.02353772, ...,  0.54150152,
#         0.24483782,  0.02356571])

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
result_test = extract_keypoints(results)

# %%
result_test
# Out:
# array([ 0.48864782,  0.2592431 , -0.95004648, ...,  0.        ,
#         0.        ,  0.        ])

# %%
np.save('0', result_test)

# %%
np.load('0.npy')
# Out:
# array([ 0.50796777,  0.28973576, -0.78618729, ...,  0.        ,
#         0.        ,  0.        ])

# %% [markdown]
# # 4. Setup Folders for Collection

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('/Users/sraswan/Documents/Workspace/holdit/backend/MP_Data') 

# Actions that we try to detect
actions = np.array(['hello', 'thanks', 'iloveyou', '_', 'iam', 'tired', 'hungry', 'good'])

# Thirty videos worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# Folder start
start_folder = 30

# %%
for action in actions: 
    # dirmax = np.max(np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int))
    for sequence in range(no_sequences):
        try: 
            # os.makedirs(os.path.join(DATA_PATH, action, str(dirmax+sequence)))
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %% [markdown]
# # 5. Collect Keypoint Values for Training and Testing

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)
#                 print(results)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (40,40), 
                               cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 0, 255), 4, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(1000)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (40,40), 
                               cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 0, 255), 4, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()
# Out:
# I0000 00:00:1705788677.152130       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 76.3), renderer: Apple M1 Pro

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 6. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'hello': 0,
#  'thanks': 1,
#  'iloveyou': 2,
#  '_': 3,
#  'iam': 4,
#  'tired': 5,
#  'hungry': 6,
#  'good': 7}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (240, 30, 1662)

# %%
np.array(labels).shape
# Out:
# (240,)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (240, 30, 1662)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
y_test.shape
# Out:
# (12, 8)

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/500
# 8/8 [==============================] - 1s 51ms/step - loss: 0.5043 - categorical_accuracy: 0.8421
# Epoch 2/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.5478 - categorical_accuracy: 0.7675
# Epoch 3/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.7006 - categorical_accuracy: 0.6623
# Epoch 4/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.9143 - categorical_accuracy: 0.5526
# Epoch 5/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.6704 - categorical_accuracy: 0.7149
# Epoch 6/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.6614 - categorical_accuracy: 0.6974
# Epoch 7/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.5603 - categorical_accuracy: 0.7851
# Epoch 8/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.5013 - categorical_accuracy: 0.8070
# Epoch 9/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.5247 - categorical_accuracy: 0.7851
# Epoch 10/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.5384 - categorical_accuracy: 0.8026
# Epoch 11/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.5928 - categorical_accuracy: 0.7632
# Epoch 12/500
# 8/8 [==============================] - 0s 58ms/step - loss: 0.5415 - categorical_accuracy: 0.7895
# Epoch 13/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.5684 - categorical_accuracy: 0.7719
# Epoch 14/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.5059 - categorical_accuracy: 0.8026
# Epoch 15/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.4943 - categorical_accuracy: 0.8333
# Epoch 16/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.5688 - categorical_accuracy: 0.7325
# Epoch 17/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.5354 - categorical_accuracy: 0.8289
# Epoch 18/500
# 8/8 [==============================] - 0s 46ms/step - loss: 0.5725 - categorical_accuracy: 0.7368
# Epoch 19/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.7675 - categorical_accuracy: 0.6316
# Epoch 20/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.6240 - categorical_accuracy: 0.7325
# Epoch 21/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.5076 - categorical_accuracy: 0.7763
# Epoch 22/500
# 8/8 [==============================] - 0s 61ms/step - loss: 0.9713 - categorical_accuracy: 0.5746
# Epoch 23/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.7854 - categorical_accuracy: 0.6096
# Epoch 24/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.6835 - categorical_accuracy: 0.7456
# Epoch 25/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.6117 - categorical_accuracy: 0.7895
# Epoch 26/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.5224 - categorical_accuracy: 0.7982
# Epoch 27/500
# 8/8 [==============================] - 0s 52ms/step - loss: 0.5443 - categorical_accuracy: 0.7675
# Epoch 28/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.5091 - categorical_accuracy: 0.7982
# Epoch 29/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.5136 - categorical_accuracy: 0.8333
# Epoch 30/500
# 8/8 [==============================] - 0s 54ms/step - loss: 0.4706 - categorical_accuracy: 0.8596
# Epoch 31/500
# 8/8 [==============================] - 0s 46ms/step - loss: 0.5167 - categorical_accuracy: 0.7719
# Epoch 32/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.6518 - categorical_accuracy: 0.7325
# Epoch 33/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.5312 - categorical_accuracy: 0.7588
# Epoch 34/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.5390 - categorical_accuracy: 0.8070
# Epoch 35/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.7724 - categorical_accuracy: 0.7105
# Epoch 36/500
# 8/8 [==============================] - 0s 52ms/step - loss: 0.5029 - categorical_accuracy: 0.7675
# Epoch 37/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.4978 - categorical_accuracy: 0.7982
# Epoch 38/500
# 8/8 [==============================] - 0s 54ms/step - loss: 0.4779 - categorical_accuracy: 0.8289
# Epoch 39/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.4630 - categorical_accuracy: 0.8947
# Epoch 40/500
# 8/8 [==============================] - 1s 58ms/step - loss: 0.4454 - categorical_accuracy: 0.8465
# Epoch 41/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.4358 - categorical_accuracy: 0.8246
# Epoch 42/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.4413 - categorical_accuracy: 0.8860
# Epoch 43/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.4287 - categorical_accuracy: 0.8553
# Epoch 44/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.4862 - categorical_accuracy: 0.8377
# Epoch 45/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.4338 - categorical_accuracy: 0.8640
# Epoch 46/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.4020 - categorical_accuracy: 0.9254
# Epoch 47/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.4076 - categorical_accuracy: 0.9079
# Epoch 48/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.7211 - categorical_accuracy: 0.6930
# Epoch 49/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.5226 - categorical_accuracy: 0.7851
# Epoch 50/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.4522 - categorical_accuracy: 0.8465
# Epoch 51/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.4123 - categorical_accuracy: 0.9123
# Epoch 52/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.4154 - categorical_accuracy: 0.8772
# Epoch 53/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.4196 - categorical_accuracy: 0.8728
# Epoch 54/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.4714 - categorical_accuracy: 0.8114
# Epoch 55/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.4287 - categorical_accuracy: 0.8772
# Epoch 56/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.3876 - categorical_accuracy: 0.9123
# Epoch 57/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.3568 - categorical_accuracy: 0.9254
# Epoch 58/500
# 8/8 [==============================] - 0s 46ms/step - loss: 0.4887 - categorical_accuracy: 0.8377
# Epoch 59/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.4894 - categorical_accuracy: 0.8158
# Epoch 60/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.5353 - categorical_accuracy: 0.7588
# Epoch 61/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.4045 - categorical_accuracy: 0.8904
# Epoch 62/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3543 - categorical_accuracy: 0.9518
# Epoch 63/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3667 - categorical_accuracy: 0.9167
# Epoch 64/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.3359 - categorical_accuracy: 0.9298
# Epoch 65/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.8265 - categorical_accuracy: 0.6623
# Epoch 66/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.5340 - categorical_accuracy: 0.8114
# Epoch 67/500
# 8/8 [==============================] - 0s 46ms/step - loss: 0.4164 - categorical_accuracy: 0.8991
# Epoch 68/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3458 - categorical_accuracy: 0.9430
# Epoch 69/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3755 - categorical_accuracy: 0.9123
# Epoch 70/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.5484 - categorical_accuracy: 0.7851
# Epoch 71/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.4119 - categorical_accuracy: 0.8816
# Epoch 72/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.4255 - categorical_accuracy: 0.8728
# Epoch 73/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3465 - categorical_accuracy: 0.9254
# Epoch 74/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.3238 - categorical_accuracy: 0.9518
# Epoch 75/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3453 - categorical_accuracy: 0.9298
# Epoch 76/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3397 - categorical_accuracy: 0.9123
# Epoch 77/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3520 - categorical_accuracy: 0.9167
# Epoch 78/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.8098 - categorical_accuracy: 0.6754
# Epoch 79/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.8390 - categorical_accuracy: 0.6754
# Epoch 80/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.8186 - categorical_accuracy: 0.6316
# Epoch 81/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.5742 - categorical_accuracy: 0.7675
# Epoch 82/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.4098 - categorical_accuracy: 0.9298
# Epoch 83/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3505 - categorical_accuracy: 0.9561
# Epoch 84/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.4250 - categorical_accuracy: 0.8860
# Epoch 85/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.5043 - categorical_accuracy: 0.8246
# Epoch 86/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3773 - categorical_accuracy: 0.9079
# Epoch 87/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.4737 - categorical_accuracy: 0.8421
# Epoch 88/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.5652 - categorical_accuracy: 0.7939
# Epoch 89/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.4570 - categorical_accuracy: 0.8421
# Epoch 90/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.3976 - categorical_accuracy: 0.8904
# Epoch 91/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3486 - categorical_accuracy: 0.9254
# Epoch 92/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2909 - categorical_accuracy: 0.9649
# Epoch 93/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3585 - categorical_accuracy: 0.9211
# Epoch 94/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.3551 - categorical_accuracy: 0.9298
# Epoch 95/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.3154 - categorical_accuracy: 0.9342
# Epoch 96/500
# 8/8 [==============================] - 0s 52ms/step - loss: 0.3036 - categorical_accuracy: 0.9474
# Epoch 97/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2912 - categorical_accuracy: 0.9474
# Epoch 98/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2629 - categorical_accuracy: 0.9605
# Epoch 99/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2577 - categorical_accuracy: 0.9561
# Epoch 100/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.3342 - categorical_accuracy: 0.9167
# Epoch 101/500
# 8/8 [==============================] - 0s 52ms/step - loss: 0.4937 - categorical_accuracy: 0.8158
# Epoch 102/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.7481 - categorical_accuracy: 0.7018
# Epoch 103/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.7762 - categorical_accuracy: 0.7193
# Epoch 104/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.6849 - categorical_accuracy: 0.6667
# Epoch 105/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.5060 - categorical_accuracy: 0.8114
# Epoch 106/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3865 - categorical_accuracy: 0.8904
# Epoch 107/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.3368 - categorical_accuracy: 0.9123
# Epoch 108/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3115 - categorical_accuracy: 0.9298
# Epoch 109/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2997 - categorical_accuracy: 0.9386
# Epoch 110/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2783 - categorical_accuracy: 0.9561
# Epoch 111/500
# 8/8 [==============================] - 0s 53ms/step - loss: 0.2924 - categorical_accuracy: 0.9386
# Epoch 112/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2974 - categorical_accuracy: 0.9474
# Epoch 113/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.4364 - categorical_accuracy: 0.8553
# Epoch 114/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.3590 - categorical_accuracy: 0.9123
# Epoch 115/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.7824 - categorical_accuracy: 0.7412
# Epoch 116/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.8709 - categorical_accuracy: 0.6711
# Epoch 117/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.5704 - categorical_accuracy: 0.8070
# Epoch 118/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3424 - categorical_accuracy: 0.9386
# Epoch 119/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2916 - categorical_accuracy: 0.9605
# Epoch 120/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2694 - categorical_accuracy: 0.9649
# Epoch 121/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2926 - categorical_accuracy: 0.9518
# Epoch 122/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2490 - categorical_accuracy: 0.9605
# Epoch 123/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2537 - categorical_accuracy: 0.9561
# Epoch 124/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2769 - categorical_accuracy: 0.9518
# Epoch 125/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2625 - categorical_accuracy: 0.9605
# Epoch 126/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2649 - categorical_accuracy: 0.9561
# Epoch 127/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2653 - categorical_accuracy: 0.9474
# Epoch 128/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2417 - categorical_accuracy: 0.9561
# Epoch 129/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2646 - categorical_accuracy: 0.9474
# Epoch 130/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2885 - categorical_accuracy: 0.9342
# Epoch 131/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3614 - categorical_accuracy: 0.8947
# Epoch 132/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3178 - categorical_accuracy: 0.9386
# Epoch 133/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2865 - categorical_accuracy: 0.9386
# Epoch 134/500
# 8/8 [==============================] - 0s 46ms/step - loss: 0.2908 - categorical_accuracy: 0.9386
# Epoch 135/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2612 - categorical_accuracy: 0.9430
# Epoch 136/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2460 - categorical_accuracy: 0.9518
# Epoch 137/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2174 - categorical_accuracy: 0.9649
# Epoch 138/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2314 - categorical_accuracy: 0.9518
# Epoch 139/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3691 - categorical_accuracy: 0.9079
# Epoch 140/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2890 - categorical_accuracy: 0.9298
# Epoch 141/500
# 8/8 [==============================] - 0s 52ms/step - loss: 0.4226 - categorical_accuracy: 0.8465
# Epoch 142/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2926 - categorical_accuracy: 0.9254
# Epoch 143/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2195 - categorical_accuracy: 0.9518
# Epoch 144/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3142 - categorical_accuracy: 0.9211
# Epoch 145/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3769 - categorical_accuracy: 0.8772
# Epoch 146/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2406 - categorical_accuracy: 0.9605
# Epoch 147/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.3515 - categorical_accuracy: 0.8816
# Epoch 148/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.4983 - categorical_accuracy: 0.8070
# Epoch 149/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.7903 - categorical_accuracy: 0.7368
# Epoch 150/500
# 8/8 [==============================] - 0s 49ms/step - loss: 1.1494 - categorical_accuracy: 0.5395
# Epoch 151/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.6477 - categorical_accuracy: 0.7544
# Epoch 152/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.4416 - categorical_accuracy: 0.8509
# Epoch 153/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.5247 - categorical_accuracy: 0.8289
# Epoch 154/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.3656 - categorical_accuracy: 0.8860
# Epoch 155/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3111 - categorical_accuracy: 0.9298
# Epoch 156/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.6148 - categorical_accuracy: 0.7500
# Epoch 157/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.6368 - categorical_accuracy: 0.7193
# Epoch 158/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.5211 - categorical_accuracy: 0.7851
# Epoch 159/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.3755 - categorical_accuracy: 0.8860
# Epoch 160/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2863 - categorical_accuracy: 0.9342
# Epoch 161/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3522 - categorical_accuracy: 0.9079
# Epoch 162/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2961 - categorical_accuracy: 0.9298
# Epoch 163/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2741 - categorical_accuracy: 0.9518
# Epoch 164/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2823 - categorical_accuracy: 0.9386
# Epoch 165/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2482 - categorical_accuracy: 0.9605
# Epoch 166/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2251 - categorical_accuracy: 0.9649
# Epoch 167/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2250 - categorical_accuracy: 0.9649
# Epoch 168/500
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2260 - categorical_accuracy: 0.9649
# Epoch 169/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2121 - categorical_accuracy: 0.9649
# Epoch 170/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2161 - categorical_accuracy: 0.9605
# Epoch 171/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2170 - categorical_accuracy: 0.9561
# Epoch 172/500
# 8/8 [==============================] - 0s 46ms/step - loss: 0.2127 - categorical_accuracy: 0.9649
# Epoch 173/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2041 - categorical_accuracy: 0.9649
# Epoch 174/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2173 - categorical_accuracy: 0.9605
# Epoch 175/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2101 - categorical_accuracy: 0.9605
# Epoch 176/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2018 - categorical_accuracy: 0.9649
# Epoch 177/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1999 - categorical_accuracy: 0.9649
# Epoch 178/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2960 - categorical_accuracy: 0.9167
# Epoch 179/500
# 8/8 [==============================] - 0s 54ms/step - loss: 0.2893 - categorical_accuracy: 0.9211
# Epoch 180/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.5206 - categorical_accuracy: 0.8246
# Epoch 181/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.5839 - categorical_accuracy: 0.8026
# Epoch 182/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.5027 - categorical_accuracy: 0.8289
# Epoch 183/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3030 - categorical_accuracy: 0.9298
# Epoch 184/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2182 - categorical_accuracy: 0.9605
# Epoch 185/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2192 - categorical_accuracy: 0.9605
# Epoch 186/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2833 - categorical_accuracy: 0.9211
# Epoch 187/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3156 - categorical_accuracy: 0.9211
# Epoch 188/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2554 - categorical_accuracy: 0.9342
# Epoch 189/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3784 - categorical_accuracy: 0.8640
# Epoch 190/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3281 - categorical_accuracy: 0.9079
# Epoch 191/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.3245 - categorical_accuracy: 0.9123
# Epoch 192/500
# 8/8 [==============================] - 1s 74ms/step - loss: 0.3463 - categorical_accuracy: 0.9079
# Epoch 193/500
# 8/8 [==============================] - 0s 51ms/step - loss: 1.4528 - categorical_accuracy: 0.5921
# Epoch 194/500
# 8/8 [==============================] - 0s 55ms/step - loss: 2.2432 - categorical_accuracy: 0.3684
# Epoch 195/500
# 8/8 [==============================] - 0s 48ms/step - loss: 1.0009 - categorical_accuracy: 0.5132
# Epoch 196/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.5424 - categorical_accuracy: 0.8114
# Epoch 197/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.3192 - categorical_accuracy: 0.9342
# Epoch 198/500
# 8/8 [==============================] - 0s 46ms/step - loss: 0.5403 - categorical_accuracy: 0.8596
# Epoch 199/500
# 8/8 [==============================] - 0s 48ms/step - loss: 6.4823 - categorical_accuracy: 0.2105
# Epoch 200/500
# 8/8 [==============================] - 0s 49ms/step - loss: 2.9374 - categorical_accuracy: 0.1404
# Epoch 201/500
# 8/8 [==============================] - 0s 47ms/step - loss: 2.2563 - categorical_accuracy: 0.2368
# Epoch 202/500
# 8/8 [==============================] - 0s 47ms/step - loss: 2.0097 - categorical_accuracy: 0.2281
# Epoch 203/500
# 8/8 [==============================] - 0s 53ms/step - loss: 1.8773 - categorical_accuracy: 0.2763
# Epoch 204/500
# 8/8 [==============================] - 0s 50ms/step - loss: 1.7737 - categorical_accuracy: 0.3070
# Epoch 205/500
# 8/8 [==============================] - 0s 51ms/step - loss: 1.6597 - categorical_accuracy: 0.3333
# Epoch 206/500
# 8/8 [==============================] - 0s 51ms/step - loss: 1.5672 - categorical_accuracy: 0.3509
# Epoch 207/500
# 8/8 [==============================] - 0s 49ms/step - loss: 1.6631 - categorical_accuracy: 0.2588
# Epoch 208/500
# 8/8 [==============================] - 0s 48ms/step - loss: 1.6362 - categorical_accuracy: 0.2588
# Epoch 209/500
# 8/8 [==============================] - 0s 57ms/step - loss: 1.6929 - categorical_accuracy: 0.2675
# Epoch 210/500
# 8/8 [==============================] - 0s 49ms/step - loss: 1.5129 - categorical_accuracy: 0.3991
# Epoch 211/500
# 8/8 [==============================] - 0s 49ms/step - loss: 1.4044 - categorical_accuracy: 0.4825
# Epoch 212/500
# 8/8 [==============================] - 0s 48ms/step - loss: 1.3597 - categorical_accuracy: 0.4342
# Epoch 213/500
# 8/8 [==============================] - 0s 51ms/step - loss: 1.3232 - categorical_accuracy: 0.4518
# Epoch 214/500
# 8/8 [==============================] - 0s 49ms/step - loss: 1.3544 - categorical_accuracy: 0.3904
# Epoch 215/500
# 8/8 [==============================] - 0s 49ms/step - loss: 1.2425 - categorical_accuracy: 0.4386
# Epoch 216/500
# 8/8 [==============================] - 0s 49ms/step - loss: 1.2801 - categorical_accuracy: 0.5175
# Epoch 217/500
# 8/8 [==============================] - 0s 49ms/step - loss: 1.4651 - categorical_accuracy: 0.4430
# Epoch 218/500
# 8/8 [==============================] - 0s 49ms/step - loss: 1.2239 - categorical_accuracy: 0.5044
# Epoch 219/500
# 8/8 [==============================] - 0s 47ms/step - loss: 1.1362 - categorical_accuracy: 0.4693
# Epoch 220/500
# 8/8 [==============================] - 0s 50ms/step - loss: 1.0937 - categorical_accuracy: 0.6404
# Epoch 221/500
# 8/8 [==============================] - 0s 48ms/step - loss: 1.0580 - categorical_accuracy: 0.6009
# Epoch 222/500
# 8/8 [==============================] - 0s 48ms/step - loss: 1.3418 - categorical_accuracy: 0.4605
# Epoch 223/500
# 8/8 [==============================] - 0s 47ms/step - loss: 1.1407 - categorical_accuracy: 0.5570
# Epoch 224/500
# 8/8 [==============================] - 0s 51ms/step - loss: 1.1209 - categorical_accuracy: 0.4518
# Epoch 225/500
# 8/8 [==============================] - 0s 51ms/step - loss: 1.2568 - categorical_accuracy: 0.5132
# Epoch 226/500
# 8/8 [==============================] - 0s 50ms/step - loss: 1.1398 - categorical_accuracy: 0.4561
# Epoch 227/500
# 8/8 [==============================] - 0s 50ms/step - loss: 1.1808 - categorical_accuracy: 0.5614
# Epoch 228/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.9763 - categorical_accuracy: 0.6711
# Epoch 229/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.9268 - categorical_accuracy: 0.6974
# Epoch 230/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.9061 - categorical_accuracy: 0.6009
# Epoch 231/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.8975 - categorical_accuracy: 0.6404
# Epoch 232/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.9355 - categorical_accuracy: 0.6096
# Epoch 233/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.9177 - categorical_accuracy: 0.6360
# Epoch 234/500
# 8/8 [==============================] - 0s 51ms/step - loss: 1.6476 - categorical_accuracy: 0.4123
# Epoch 235/500
# 8/8 [==============================] - 0s 50ms/step - loss: 1.0043 - categorical_accuracy: 0.6184
# Epoch 236/500
# 8/8 [==============================] - 0s 49ms/step - loss: 1.5139 - categorical_accuracy: 0.4167
# Epoch 237/500
# 8/8 [==============================] - 0s 48ms/step - loss: 1.0487 - categorical_accuracy: 0.5702
# Epoch 238/500
# 8/8 [==============================] - 0s 50ms/step - loss: 1.3235 - categorical_accuracy: 0.5482
# Epoch 239/500
# 8/8 [==============================] - 0s 49ms/step - loss: 1.2614 - categorical_accuracy: 0.5175
# Epoch 240/500
# 8/8 [==============================] - 0s 51ms/step - loss: 1.0022 - categorical_accuracy: 0.5921
# Epoch 241/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.8165 - categorical_accuracy: 0.6930
# Epoch 242/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.7546 - categorical_accuracy: 0.8026
# Epoch 243/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.6317 - categorical_accuracy: 0.9211
# Epoch 244/500
# 8/8 [==============================] - 0s 54ms/step - loss: 0.6539 - categorical_accuracy: 0.8728
# Epoch 245/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.5228 - categorical_accuracy: 0.9342
# Epoch 246/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.7921 - categorical_accuracy: 0.7368
# Epoch 247/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.5632 - categorical_accuracy: 0.8860
# Epoch 248/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.5538 - categorical_accuracy: 0.8772
# Epoch 249/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.6446 - categorical_accuracy: 0.7456
# Epoch 250/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.5552 - categorical_accuracy: 0.8421
# Epoch 251/500
# 8/8 [==============================] - 0s 49ms/step - loss: 1.1659 - categorical_accuracy: 0.5877
# Epoch 252/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.8613 - categorical_accuracy: 0.6711
# Epoch 253/500
# 8/8 [==============================] - 0s 53ms/step - loss: 0.5712 - categorical_accuracy: 0.8421
# Epoch 254/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.4386 - categorical_accuracy: 0.9079
# Epoch 255/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3458 - categorical_accuracy: 0.9649
# Epoch 256/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.3486 - categorical_accuracy: 0.9474
# Epoch 257/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.3014 - categorical_accuracy: 0.9649
# Epoch 258/500
# 8/8 [==============================] - 0s 54ms/step - loss: 0.2808 - categorical_accuracy: 0.9693
# Epoch 259/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3333 - categorical_accuracy: 0.9386
# Epoch 260/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2765 - categorical_accuracy: 0.9605
# Epoch 261/500
# 8/8 [==============================] - 1s 65ms/step - loss: 0.3129 - categorical_accuracy: 0.9298
# Epoch 262/500
# 8/8 [==============================] - 0s 55ms/step - loss: 0.6601 - categorical_accuracy: 0.7632
# Epoch 263/500
# 8/8 [==============================] - 0s 50ms/step - loss: 1.1349 - categorical_accuracy: 0.6140
# Epoch 264/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.8797 - categorical_accuracy: 0.6316
# Epoch 265/500
# 8/8 [==============================] - 0s 49ms/step - loss: 1.2034 - categorical_accuracy: 0.5351
# Epoch 266/500
# 8/8 [==============================] - 0s 50ms/step - loss: 1.0280 - categorical_accuracy: 0.6272
# Epoch 267/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.8681 - categorical_accuracy: 0.6140
# Epoch 268/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.6369 - categorical_accuracy: 0.7939
# Epoch 269/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.4647 - categorical_accuracy: 0.8904
# Epoch 270/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3873 - categorical_accuracy: 0.9254
# Epoch 271/500
# 8/8 [==============================] - 0s 55ms/step - loss: 0.3810 - categorical_accuracy: 0.9474
# Epoch 272/500
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4197 - categorical_accuracy: 0.8772
# Epoch 273/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.4289 - categorical_accuracy: 0.8596
# Epoch 274/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2973 - categorical_accuracy: 0.9649
# Epoch 275/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.3725 - categorical_accuracy: 0.9035
# Epoch 276/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3465 - categorical_accuracy: 0.9167
# Epoch 277/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2916 - categorical_accuracy: 0.9386
# Epoch 278/500
# 8/8 [==============================] - 0s 55ms/step - loss: 0.2646 - categorical_accuracy: 0.9605
# Epoch 279/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2539 - categorical_accuracy: 0.9605
# Epoch 280/500
# 8/8 [==============================] - 0s 54ms/step - loss: 0.2174 - categorical_accuracy: 0.9649
# Epoch 281/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2009 - categorical_accuracy: 0.9693
# Epoch 282/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2023 - categorical_accuracy: 0.9693
# Epoch 283/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1884 - categorical_accuracy: 0.9693
# Epoch 284/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1923 - categorical_accuracy: 0.9693
# Epoch 285/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2003 - categorical_accuracy: 0.9693
# Epoch 286/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2657 - categorical_accuracy: 0.9386
# Epoch 287/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.3423 - categorical_accuracy: 0.8904
# Epoch 288/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1957 - categorical_accuracy: 0.9649
# Epoch 289/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2121 - categorical_accuracy: 0.9649
# Epoch 290/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1911 - categorical_accuracy: 0.9649
# Epoch 291/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1821 - categorical_accuracy: 0.9693
# Epoch 292/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2267 - categorical_accuracy: 0.9561
# Epoch 293/500
# 8/8 [==============================] - 0s 53ms/step - loss: 0.2086 - categorical_accuracy: 0.9605
# Epoch 294/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1861 - categorical_accuracy: 0.9693
# Epoch 295/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1771 - categorical_accuracy: 0.9693
# Epoch 296/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1815 - categorical_accuracy: 0.9693
# Epoch 297/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1674 - categorical_accuracy: 0.9693
# Epoch 298/500
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2102 - categorical_accuracy: 0.9561
# Epoch 299/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1778 - categorical_accuracy: 0.9693
# Epoch 300/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1838 - categorical_accuracy: 0.9693
# Epoch 301/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1649 - categorical_accuracy: 0.9693
# Epoch 302/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1705 - categorical_accuracy: 0.9693
# Epoch 303/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1598 - categorical_accuracy: 0.9693
# Epoch 304/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1569 - categorical_accuracy: 0.9693
# Epoch 305/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1617 - categorical_accuracy: 0.9693
# Epoch 306/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2253 - categorical_accuracy: 0.9605
# Epoch 307/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1991 - categorical_accuracy: 0.9649
# Epoch 308/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2283 - categorical_accuracy: 0.9474
# Epoch 309/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.5179 - categorical_accuracy: 0.8465
# Epoch 310/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.8096 - categorical_accuracy: 0.7544
# Epoch 311/500
# 8/8 [==============================] - 0s 51ms/step - loss: 1.0904 - categorical_accuracy: 0.6667
# Epoch 312/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.7425 - categorical_accuracy: 0.7412
# Epoch 313/500
# 8/8 [==============================] - 0s 58ms/step - loss: 0.4515 - categorical_accuracy: 0.9211
# Epoch 314/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.3553 - categorical_accuracy: 0.9035
# Epoch 315/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2869 - categorical_accuracy: 0.9518
# Epoch 316/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2554 - categorical_accuracy: 0.9605
# Epoch 317/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2328 - categorical_accuracy: 0.9649
# Epoch 318/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2044 - categorical_accuracy: 0.9693
# Epoch 319/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2096 - categorical_accuracy: 0.9649
# Epoch 320/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1984 - categorical_accuracy: 0.9649
# Epoch 321/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1868 - categorical_accuracy: 0.9693
# Epoch 322/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1867 - categorical_accuracy: 0.9737
# Epoch 323/500
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1816 - categorical_accuracy: 0.9693
# Epoch 324/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1724 - categorical_accuracy: 0.9737
# Epoch 325/500
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1982 - categorical_accuracy: 0.9649
# Epoch 326/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1934 - categorical_accuracy: 0.9693
# Epoch 327/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2678 - categorical_accuracy: 0.9474
# Epoch 328/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.7228 - categorical_accuracy: 0.7368
# Epoch 329/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.4249 - categorical_accuracy: 0.8333
# Epoch 330/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2680 - categorical_accuracy: 0.9298
# Epoch 331/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1917 - categorical_accuracy: 0.9693
# Epoch 332/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1652 - categorical_accuracy: 0.9693
# Epoch 333/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1610 - categorical_accuracy: 0.9693
# Epoch 334/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1531 - categorical_accuracy: 0.9649
# Epoch 335/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2304 - categorical_accuracy: 0.9167
# Epoch 336/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2987 - categorical_accuracy: 0.8947
# Epoch 337/500
# 8/8 [==============================] - 0s 46ms/step - loss: 0.2342 - categorical_accuracy: 0.9430
# Epoch 338/500
# 8/8 [==============================] - 0s 52ms/step - loss: 0.3212 - categorical_accuracy: 0.9211
# Epoch 339/500
# 8/8 [==============================] - 0s 53ms/step - loss: 0.6127 - categorical_accuracy: 0.8158
# Epoch 340/500
# 8/8 [==============================] - 0s 56ms/step - loss: 0.4396 - categorical_accuracy: 0.8070
# Epoch 341/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.6365 - categorical_accuracy: 0.7719
# Epoch 342/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3541 - categorical_accuracy: 0.8728
# Epoch 343/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.3100 - categorical_accuracy: 0.9167
# Epoch 344/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2156 - categorical_accuracy: 0.9561
# Epoch 345/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1874 - categorical_accuracy: 0.9649
# Epoch 346/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1706 - categorical_accuracy: 0.9693
# Epoch 347/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1828 - categorical_accuracy: 0.9693
# Epoch 348/500
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2155 - categorical_accuracy: 0.9605
# Epoch 349/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1703 - categorical_accuracy: 0.9693
# Epoch 350/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1976 - categorical_accuracy: 0.9693
# Epoch 351/500
# 8/8 [==============================] - 0s 46ms/step - loss: 0.1992 - categorical_accuracy: 0.9649
# Epoch 352/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2076 - categorical_accuracy: 0.9518
# Epoch 353/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2233 - categorical_accuracy: 0.9474
# Epoch 354/500
# 8/8 [==============================] - 0s 52ms/step - loss: 0.4921 - categorical_accuracy: 0.8246
# Epoch 355/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2271 - categorical_accuracy: 0.9342
# Epoch 356/500
# 8/8 [==============================] - 0s 53ms/step - loss: 0.3313 - categorical_accuracy: 0.8860
# Epoch 357/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2526 - categorical_accuracy: 0.9386
# Epoch 358/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2380 - categorical_accuracy: 0.9474
# Epoch 359/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2189 - categorical_accuracy: 0.9430
# Epoch 360/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1776 - categorical_accuracy: 0.9693
# Epoch 361/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1619 - categorical_accuracy: 0.9693
# Epoch 362/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1551 - categorical_accuracy: 0.9693
# Epoch 363/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1483 - categorical_accuracy: 0.9737
# Epoch 364/500
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1450 - categorical_accuracy: 0.9693
# Epoch 365/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1550 - categorical_accuracy: 0.9737
# Epoch 366/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1421 - categorical_accuracy: 0.9737
# Epoch 367/500
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1404 - categorical_accuracy: 0.9737
# Epoch 368/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1522 - categorical_accuracy: 0.9693
# Epoch 369/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1482 - categorical_accuracy: 0.9737
# Epoch 370/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1350 - categorical_accuracy: 0.9693
# Epoch 371/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1484 - categorical_accuracy: 0.9693
# Epoch 372/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1612 - categorical_accuracy: 0.9649
# Epoch 373/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1825 - categorical_accuracy: 0.9693
# Epoch 374/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1675 - categorical_accuracy: 0.9605
# Epoch 375/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1542 - categorical_accuracy: 0.9693
# Epoch 376/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1697 - categorical_accuracy: 0.9649
# Epoch 377/500
# 8/8 [==============================] - 0s 46ms/step - loss: 0.1692 - categorical_accuracy: 0.9693
# Epoch 378/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1437 - categorical_accuracy: 0.9737
# Epoch 379/500
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1556 - categorical_accuracy: 0.9605
# Epoch 380/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1317 - categorical_accuracy: 0.9693
# Epoch 381/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1279 - categorical_accuracy: 0.9737
# Epoch 382/500
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1225 - categorical_accuracy: 0.9693
# Epoch 383/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1273 - categorical_accuracy: 0.9737
# Epoch 384/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1278 - categorical_accuracy: 0.9737
# Epoch 385/500
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1375 - categorical_accuracy: 0.9737
# Epoch 386/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1266 - categorical_accuracy: 0.9737
# Epoch 387/500
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1424 - categorical_accuracy: 0.9737
# Epoch 388/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1470 - categorical_accuracy: 0.9693
# Epoch 389/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1454 - categorical_accuracy: 0.9693
# Epoch 390/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1322 - categorical_accuracy: 0.9693
# Epoch 391/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1198 - categorical_accuracy: 0.9693
# Epoch 392/500
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1214 - categorical_accuracy: 0.9693
# Epoch 393/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1229 - categorical_accuracy: 0.9693
# Epoch 394/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1161 - categorical_accuracy: 0.9781
# Epoch 395/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1123 - categorical_accuracy: 0.9737
# Epoch 396/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1191 - categorical_accuracy: 0.9693
# Epoch 397/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1605 - categorical_accuracy: 0.9518
# Epoch 398/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2593 - categorical_accuracy: 0.9298
# Epoch 399/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.5561 - categorical_accuracy: 0.8553
# Epoch 400/500
# 8/8 [==============================] - 0s 46ms/step - loss: 0.7769 - categorical_accuracy: 0.7193
# Epoch 401/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.4869 - categorical_accuracy: 0.8421
# Epoch 402/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.3177 - categorical_accuracy: 0.9298
# Epoch 403/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.9431 - categorical_accuracy: 0.7807
# Epoch 404/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.8198 - categorical_accuracy: 0.7193
# Epoch 405/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2788 - categorical_accuracy: 0.9167
# Epoch 406/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.3281 - categorical_accuracy: 0.9123
# Epoch 407/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2434 - categorical_accuracy: 0.9605
# Epoch 408/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1857 - categorical_accuracy: 0.9649
# Epoch 409/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1623 - categorical_accuracy: 0.9693
# Epoch 410/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1559 - categorical_accuracy: 0.9693
# Epoch 411/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1493 - categorical_accuracy: 0.9693
# Epoch 412/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1456 - categorical_accuracy: 0.9693
# Epoch 413/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1441 - categorical_accuracy: 0.9693
# Epoch 414/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1410 - categorical_accuracy: 0.9693
# Epoch 415/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1414 - categorical_accuracy: 0.9693
# Epoch 416/500
# 8/8 [==============================] - 0s 46ms/step - loss: 0.1388 - categorical_accuracy: 0.9737
# Epoch 417/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2375 - categorical_accuracy: 0.9254
# Epoch 418/500
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1962 - categorical_accuracy: 0.9561
# Epoch 419/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1575 - categorical_accuracy: 0.9693
# Epoch 420/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1564 - categorical_accuracy: 0.9649
# Epoch 421/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1384 - categorical_accuracy: 0.9693
# Epoch 422/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1367 - categorical_accuracy: 0.9693
# Epoch 423/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1460 - categorical_accuracy: 0.9649
# Epoch 424/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1431 - categorical_accuracy: 0.9693
# Epoch 425/500
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1364 - categorical_accuracy: 0.9693
# Epoch 426/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1237 - categorical_accuracy: 0.9737
# Epoch 427/500
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1253 - categorical_accuracy: 0.9693
# Epoch 428/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1215 - categorical_accuracy: 0.9737
# Epoch 429/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1247 - categorical_accuracy: 0.9737
# Epoch 430/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1997 - categorical_accuracy: 0.9693
# Epoch 431/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1773 - categorical_accuracy: 0.9605
# Epoch 432/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1873 - categorical_accuracy: 0.9474
# Epoch 433/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1639 - categorical_accuracy: 0.9649
# Epoch 434/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2140 - categorical_accuracy: 0.9518
# Epoch 435/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1822 - categorical_accuracy: 0.9649
# Epoch 436/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1767 - categorical_accuracy: 0.9605
# Epoch 437/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1916 - categorical_accuracy: 0.9693
# Epoch 438/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2460 - categorical_accuracy: 0.9254
# Epoch 439/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2739 - categorical_accuracy: 0.9211
# Epoch 440/500
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1719 - categorical_accuracy: 0.9649
# Epoch 441/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1935 - categorical_accuracy: 0.9649
# Epoch 442/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1753 - categorical_accuracy: 0.9561
# Epoch 443/500
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1536 - categorical_accuracy: 0.9737
# Epoch 444/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1535 - categorical_accuracy: 0.9737
# Epoch 445/500
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2038 - categorical_accuracy: 0.9211
# Epoch 446/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1494 - categorical_accuracy: 0.9693
# Epoch 447/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1496 - categorical_accuracy: 0.9737
# Epoch 448/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1371 - categorical_accuracy: 0.9737
# Epoch 449/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1370 - categorical_accuracy: 0.9737
# Epoch 450/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1353 - categorical_accuracy: 0.9737
# Epoch 451/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1277 - categorical_accuracy: 0.9737
# Epoch 452/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2693 - categorical_accuracy: 0.9211
# Epoch 453/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2728 - categorical_accuracy: 0.9167
# Epoch 454/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.4732 - categorical_accuracy: 0.8465
# Epoch 455/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.9540 - categorical_accuracy: 0.7281
# Epoch 456/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.5032 - categorical_accuracy: 0.8202
# Epoch 457/500
# 8/8 [==============================] - 0s 52ms/step - loss: 0.4153 - categorical_accuracy: 0.8509
# Epoch 458/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2671 - categorical_accuracy: 0.9079
# Epoch 459/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3757 - categorical_accuracy: 0.8377
# Epoch 460/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2215 - categorical_accuracy: 0.9342
# Epoch 461/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2005 - categorical_accuracy: 0.9605
# Epoch 462/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1566 - categorical_accuracy: 0.9737
# Epoch 463/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1411 - categorical_accuracy: 0.9737
# Epoch 464/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1367 - categorical_accuracy: 0.9737
# Epoch 465/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1326 - categorical_accuracy: 0.9737
# Epoch 466/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1380 - categorical_accuracy: 0.9737
# Epoch 467/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1312 - categorical_accuracy: 0.9693
# Epoch 468/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1300 - categorical_accuracy: 0.9737
# Epoch 469/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1300 - categorical_accuracy: 0.9737
# Epoch 470/500
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1291 - categorical_accuracy: 0.9737
# Epoch 471/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1356 - categorical_accuracy: 0.9737
# Epoch 472/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1496 - categorical_accuracy: 0.9693
# Epoch 473/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1636 - categorical_accuracy: 0.9693
# Epoch 474/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1342 - categorical_accuracy: 0.9737
# Epoch 475/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1363 - categorical_accuracy: 0.9693
# Epoch 476/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1222 - categorical_accuracy: 0.9737
# Epoch 477/500
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1275 - categorical_accuracy: 0.9737
# Epoch 478/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1211 - categorical_accuracy: 0.9737
# Epoch 479/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1375 - categorical_accuracy: 0.9737
# Epoch 480/500
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1142 - categorical_accuracy: 0.9737
# Epoch 481/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1136 - categorical_accuracy: 0.9693
# Epoch 482/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1167 - categorical_accuracy: 0.9737
# Epoch 483/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1217 - categorical_accuracy: 0.9737
# Epoch 484/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1290 - categorical_accuracy: 0.9737
# Epoch 485/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1216 - categorical_accuracy: 0.9737
# Epoch 486/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1258 - categorical_accuracy: 0.9737
# Epoch 487/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1587 - categorical_accuracy: 0.9693
# Epoch 488/500
# 8/8 [==============================] - 0s 50ms/step - loss: 1.1007 - categorical_accuracy: 0.6667
# Epoch 489/500
# 8/8 [==============================] - 0s 52ms/step - loss: 1.1815 - categorical_accuracy: 0.6009
# Epoch 490/500
# 8/8 [==============================] - 1s 68ms/step - loss: 4.4437 - categorical_accuracy: 0.2939
# Epoch 491/500
# 8/8 [==============================] - 0s 49ms/step - loss: 6.3303 - categorical_accuracy: 0.1404
# Epoch 492/500
# 8/8 [==============================] - 0s 61ms/step - loss: 1.7228 - categorical_accuracy: 0.3114
# Epoch 493/500
# 8/8 [==============================] - 0s 50ms/step - loss: 1.2627 - categorical_accuracy: 0.4079
# Epoch 494/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.9548 - categorical_accuracy: 0.6579
# Epoch 495/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.7616 - categorical_accuracy: 0.8904
# Epoch 496/500
# 8/8 [==============================] - 0s 54ms/step - loss: 0.6131 - categorical_accuracy: 0.9474
# Epoch 497/500
# 8/8 [==============================] - 0s 54ms/step - loss: 0.5502 - categorical_accuracy: 0.8991
# Epoch 498/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.4625 - categorical_accuracy: 0.9518
# Epoch 499/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.5078 - categorical_accuracy: 0.8728
# Epoch 500/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.7087 - categorical_accuracy: 0.7500

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_24 (LSTM)              (None, 30, 64)            442112
#
#  lstm_25 (LSTM)              (None, 30, 128)           98816
#
#  lstm_26 (LSTM)              (None, 64)                49408
#
#  dense_24 (Dense)            (None, 64)                4160
#
#  dense_25 (Dense)            (None, 32)                2080
#
#  dense_26 (Dense)            (None, 8)                 264
#
# =================================================================
# Total params: 596840 (2.28 MB)
# Trainable params: 596840 (2.28 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # 8. Make Predictions

# %%
res = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 23ms/step

# %%
actions[np.argmax(res[4])]
# Out:
# 'good'

# %%
actions[np.argmax(y_test[4])]
# Out:
# 'good'

# %% [markdown]
# # 9. Save Weights

# %%
model.save('action.h5')
# Out:
# /Users/sraswan/Documents/Workspace/holdit/.venv/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
del model

# %%
model.load_weights('action.h5')

# %% [markdown]
# # 10. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 22ms/step

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[11,  0],
#         [ 0,  1]],
#
#        [[ 7,  3],
#         [ 0,  2]],
#
#        [[ 8,  0],
#         [ 3,  1]],
#
#        [[ 9,  0],
#         [ 0,  3]],
#
#        [[11,  0],
#         [ 0,  1]],
#
#        [[11,  0],
#         [ 0,  1]]])

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.75

# %% [markdown]
# # 11. Test in Real Time

# %%
from scipy import stats

# %%
# colors = [(245,117,16), (117,245,16), (16,117,245)]
colors = [(255, 0, 0), (255, 0, 0), (255, 0, 0), (255, 0, 0), (255, 0, 0), (255, 0, 0), (255, 0, 0), (255, 0, 0)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
plt.figure(figsize=(18,18))
plt.imshow(prob_viz(res, actions, image, colors))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[240], line 2
#       1 plt.figure(figsize=(18,18))
# ----> 2 plt.imshow(prob_viz(res, actions, image, colors))
#
# Cell In[239], line 6, in prob_viz(res, actions, input_frame, colors)
#       4 output_frame = input_frame.copy()
#       5 for num, prob in enumerate(res):
# ----> 6     cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
#       7     cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
#       9 return output_frame
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# I0000 00:00:1705790315.323204       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 76.3), renderer: Apple M1 Pro
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# iam
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iam
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iam
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# hungry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hungry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# tired
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# tired
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# tired
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# tired
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# tired
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# tired
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# tired
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iam
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iam
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iam
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hungry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ...
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# _
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# _
